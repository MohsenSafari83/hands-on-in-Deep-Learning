# %% [markdown]
# #Gradient Descent

# %% [markdown]
# Gradient descent is one of the most important algorithms in all of machine learning and deep learning. It is an extremely powerful **optimization algorithm** that can train linear regression, logistic regression, and neural network models

# %% [markdown]
# ##What is Gradient Descent?

# %% [markdown]
# **Gradient descent** is an optimization algorithm. It is used to **find the minimum value of a function** more quickly. The definition of gradient descent is rather simple. It is an algorithm to find the minimum of a convex function. To do this, it **iteratively** changes the parameters of the function in question. It is an algorithm that is used, for example, in linear regression.
#
# A **convex function** is a function that looks like a beautiful valley with a global minimum in the center. Conversely, a non-convex function is a function that has **several local minima**, and the gradient descent algorithm **hould not be used** on these functions at the risk of **getting stuck at the first minima encountered**.

# %% [markdown]
#  It is very important in machine learning, where it is used to **minimize a cost function**. The latter is used to **determine the best prediction model** in data analysis. **The more the cost is minimized, the more the machine will be able to make good predictions**.

# %% [markdown]
# **Convex Functions:**
# - A function is convex if any line segment
# between points on the curve lies above or on
# the curve.
# - Convex functions are easier to optimize, as
# they have a single global minimum.
# - Numerical methods like Gradient Descent are
# guaranteed to reach the global minimum in
# convex functions.

# %% [markdown]
# **Non-Convex Functions:**
# - Characterized by multiple local minima and saddle
# points.
# - Global Minimum: Overall lowest point.
# - Local Minimum: Lower than nearby points, but not
# the lowest overall.
# - Saddle Points: Regions where the gradient is close
# to zero but can increase or decrease in other
# directions.
#
# - Finding the global minimum is more complex in
# non-convex functions.

# %% [markdown]
# ![Saddle_point.svg.png](data:image/png;base64,...)
#
# Saddle Point. Source: Wikipedia

# %% [markdown]
# ![convex.avif](data:image/avif;base64,...)

# %% [markdown]
# ##types of gradient descent

# %% [markdown]
# **1.Batch gradient descent**
# - Uses the entire dataset to compute the gradient before updating parameters.
# - More stable but computationally expensive for large datasets.
# ![Batch-Gradient-Descent.webp](data:image/webp;base64,...)
#
# **2.Stochastic gradient descent**
# - Updates parameters after each training example, making it faster and more dynamic.
# - Can converge faster but introduces more noise.
# ![Stochastic-Gradient-Descent.webp](data:image/webp;base64,...)
#
# **3.Mini-batch gradient descent**
# - A middle ground between batch and stochastic gradient descent.
# - Uses small random batches of data, balancing speed and stability.
# ![Mini-Batch-Gradient-Descent.webp](data:image/webp;base64,...)
#
# **4.Momentum-Based Gradient Descent:**\
# Momentum-Based Gradient Descent is an enhancement of standard gradient descent algorithm that aims to accelerate convergence particularly in the presence of high curvature, small but consistent gradients or noisy gradients. It introduces a velocity term that accumulates the gradient of the loss function over time thereby smoothing the path taken by the parameters.
# ![Momentum-Based-Gradient-Descent.webp](data:image/webp;base64,...)

# %% [markdown]
# ![Different-Variants-of-Gradient-Descent.webp](data:image/webp;base64,...)

# %% [markdown]
# ## The importance of gradient descent

# %% [markdown]
# Thanks to this algorithm, the machine learns by finding the best model. Remember that minimizing the cost function means **finding the parameters** a, b, c, etc., that give the **smallest errors** between our model and the y points of the dataset. Once the cost function is minimized, this opens the door to building accurate models.
#
# In machine learning, the gradient descent consists of **repeating this method in a loop** until finding a minimum for the cost function. This is why it is called an **iterative algorithm** and why it requires a lot of calculation.

# %% [markdown]
# ![gradient.webp](data:image/webp;base64,...)

# %% [markdown]
# ##Learning Rate: the Role of the Hyper-parameter

# %% [markdown]
# **What is the learning rate in gradient descent?**
#
# **The learning rate** is a hyperparameter that controls the size of the steps taken toward the minimum of the cost function. A smaller learning rate results in slower convergence, while a larger learning rate may cause the algorithm to overshoot the minimum.

# %% [markdown]
# In machine learning, we call this kind of factor a **hyper-parameter** because it is not strictly speaking a parameter of our model, but it still has an impact on the final performance of our model

# %% [markdown]
# The learning rate (**often noted α or sometimes η**) indicates the speed at which the coefficients evolve. This quantity can be fixed or variable.\
# One of the most popular methods at the moment is called **Adam**, which has a learning rate that scales over time.

# %% [markdown]
# There are many scenarios to expect and to take into consideration while using gradient descent :

# %% [markdown]
# ![image3_jinaje.avif](data:image/avif;base64,...)

# %% [markdown]
# **Learning rate too high:**
# - If the learning rate is too big, then you will make too big steps in the gradient descent.
# - This has the advantage of going down quickly to the minimum of the cost function, but you risk missing this minimum by oscillating around it at infinity.
# **Learning rate too small:**
# - if Learning rate is too small, then you risk taking an infinite amount of time before converging to the minimum of the cost function
# - It's a bit like choosing to go millimeter by millimeter up the mountain to find the lowest point in the valley.

# %% [markdown]
# ###Why are learning rates so important?

# %% [markdown]
# It is essential to set learning rates to appropriate values to help the descent of slopes reach local minimums. Therefore, **it would be best not to set them too high or too low.**

# %% [markdown]
# ![image2_azbk2a.avif](data:image/avif;base64,...)

# %% [markdown]
# ###How to find the best learning rates

# %% [markdown]
# Unfortunately, there is no magic formula to find the right learning rate. Most of the time, you have to **fumble around and try several values before you find the right one**. This is called **hyperparameter tuning**, and there are different strategies to do this properly.

# %% [markdown]
# ##Gradient Descent and UpdatingWeights

# %% [markdown]
# ### Weight Update Rule
#
# The **weight update rule** in Gradient Descent is defined as:
#
# $$
# w_{\text{new}} = w_{\text{old}} - \eta \cdot \frac{\partial L}{\partial w}
# $$
#
# Where:
# - **η (eta)** → the *learning rate* (step size).
# - **∂L/∂w** → the *gradient of the loss function* with respect to **w**.
#
# This rule updates the model parameters iteratively to minimize the loss function.

# %% [markdown]
# ### Steps in Gradient Descent
#
# 1. **Compute the gradient** of the loss function.
# 2. **Update the weights** using the weight update rule.
# 3. **Repeat** the process until convergence (when the loss stops decreasing).

# %% [markdown]
# ![image1_xiivzu.avif](data:image/avif;base64,...)

# %% [markdown]
# ## Advantages and Disadvantages of Gradient Descent
#
# ### **Advantages**
# - **Higher accuracy:** Gradient descent uses the average gradient of the entire dataset, resulting in more accurate updates to the model’s parameters.
# - **Predictable convergence behaviour:** Unlike SGD, gradient descent has a more predictable convergence behaviour, making it easier to fine-tune the learning rate and other hyperparameters.
# - **Robust to noise:** Because it uses the average gradient, gradient descent is less sensitive to noisy data than SGD.
#
# ### **Disadvantages**
# - **Slower speed:** Gradient descent requires calculating the gradient for the entire dataset in each iteration, making it much slower than SGD, especially for large datasets.
# - **Greater memory requirements:** Due to the need to store the entire dataset for each iteration, gradient descent requires more memory than SGD.
#
# ---
#
# ## Applications of Stochastic Gradient Descent (SGD)
# Stochastic gradient descent is commonly used in scenarios where the dataset is large and computational resources are limited. Examples include:
#
# - Training deep learning models (often combined with momentum or adaptive learning rates)
# - Large-scale image recognition tasks
# - Natural language processing tasks such as text classification or sentiment analysis
#
# ---
#
# ## Applications of Gradient Descent
# Gradient descent is typically used in situations where the dataset is smaller, or where accuracy is more important than speed. Common examples include:
#
# - Linear regression and logistic regression models
# - Support vector machines
# - Smaller-scale neural network training
#
# ---
#
# **Summary:**
# Gradient Descent is accurate but computationally heavy.
# Stochastic Gradient Descent is faster and more scalable, making it ideal for large datasets.

# %% [markdown]
# #Backpropagation
# Backpropagation is an essential part of modern neural network training, enabling these sophisticated algorithms to learn from training datasets and improve over time.
# [This video explains the intuition behind backpropagation:](https://www.youtube.com/watch?v=Ilg3gGewQ5U)

# %% [markdown]
# ##What is backpropagation?

# %% [markdown]
# **Backpropagation** is the algorithm used to train neural networks by calculating the **error** at the output and propagating it backward through the network to adjust the weights

# %% [markdown]
# ##How Does Backpropagation Work?

# %% [markdown]
# ![image_8ee636b259.avif](data:image/avif;base64,...)

# %% [markdown]
# **Forward pass:** \
# This is the first step of the backpropagation process, and it’s illustrated below:
#
# - The input  data  is fed to the input layer
# - Then, each input is multiplied by its corresponding weight, and the results are passed to the neurons of the hidden layers.
# - Those neurons apply an activation function to the weighted inputs they receive, and the result passes to the next layer.\
#
# **Errors calculation:**
# - The process continues until the output layer generates the final output (o/p).
# - The output of the network is then compared to the ground truth (desired output), and the difference is calculated, resulting in an error value.
#
# **Backward pass:**
# This is an actual backpropagation step, and can not be performed without the above forward and error calculation steps
# - The error value obtained previously is used to calculate the gradient of the loss function.
# - The gradient of the error is propagated back through the network, starting from the output layer to the hidden layers.
# - As the error gradient propagates back, the weights (represented by the lines connecting the nodes) are updated according to their contribution to the error. This involves taking the derivative of the error with respect to each weight, which indicates how much a change in the weight would change the error.
# - The learning rate determines the size of the weight updates. A smaller learning rate means than the weights are updated by a smaller amount, and vice-versa.
#
# **Weight updates:**
# - The weights are updated in the opposite direction of the gradient, leading to the name “gradient descent.” It aims to reduce the error in the next forward pass.
# - This process of forward pass, error calculation, backward pass, and weights update continues for multiple epochs until the network performance reaches a satisfactory level or stops improving significantly.

# %% [markdown]
# ![image_15833a25a7.avif](data:image/avif;base64,...)

# %% [markdown]
# ### Backpropagation: Advantages and Limitations
#
# | **Aspect** | **Description** |
# |-------------|----------------|
# | **Ease of Implementation** | Accessible through multiple deep learning libraries such as **PyTorch** and **Keras**, facilitating its use in diverse applications. |
# | **Programming Simplicity** | Simplified coding with framework abstraction, reducing the need for complex mathematics. |
# | **Flexibility** | Adaptable to diverse architectures, suitable for a broad spectrum of AI challenges. |

# %% [markdown]
# ### Limitations and Challenges
#
# | **Challenge** | **Description** |
# |----------------|----------------|
# | **Data Quality** | Poor data quality (noise, incompleteness, or bias) can lead to inaccurate models, as backpropagation learns exactly what it is given. |
# | **Training Duration** | Backpropagation often requires extensive training time, which can be impractical for large networks. |
# | **Matrix-Based Complexity** | Matrix operations scale with network size, increasing computational demand and potentially exceeding available resources. |
